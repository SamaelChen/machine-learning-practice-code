# %%
# %matplotlib inline
import os
import shutil
import sys
import numpy as np
import pandas as pd
import mxnet as mx
from mxnet import gluon
from mxnet import image
from mxnet import nd
from mxnet import init
from mxnet import autograd
from mxnet.gluon.data import vision
from mxnet.gluon import nn
from mxnet.gluon.model_zoo import vision as models
from PIL import Image
from time import time
from sklearn.model_selection import train_test_split

# %%
def mkdir_if_not_exist(path):
    if not os.path.exists(os.path.join(*path)):
        os.makedirs(os.path.join(*path))


def reorg_data(label_file, train_dir, test_dir, input_dir, valid_ratio):
    labels = pd.read_csv(label_file)
    labels = labels.sort_values('id')
    files = os.listdir(train_dir)
    files.sort()
    count = 0
    idx = np.arange(len(files))
    np.random.shuffle(idx)
    shutil.rmtree(os.path.join(input_dir, 'train'))
    shutil.rmtree(os.path.join(input_dir, 'valid'))
    for i in idx:
        if count < valid_ratio * len(files):
            mkdir_if_not_exist([input_dir, 'train', labels['breed'][i]])
            shutil.copy(os.path.join(train_dir, files[i]), os.path.join(input_dir, 'train', labels['breed'][i]))
        else:
            mkdir_if_not_exist([input_dir, 'valid', labels['breed'][i]])
            shutil.copy(os.path.join(train_dir, files[i]), os.path.join(input_dir, 'valid', labels['breed'][i]))
        count += 1
    for file in os.listdir(test_dir):
        mkdir_if_not_exist([input_dir, 'test', 'unknown'])
        shutil.copy(os.path.join(test_dir, file), os.path.join(input_dir, 'test', 'unknown'))

# %%
label_file = '/home/samael/kaggle/dogs/labels.csv'
train_dir = '/home/samael/kaggle/dogs/train/'
test_dir = '/home/samael/kaggle/dogs/test/'
input_dir = '/home/samael/kaggle/dogs/data/'
reorg_data(label_file, train_dir, test_dir, input_dir, valid_ratio=0.8)

# %%
import re
extra_dir = '/home/samael/kaggle/dogs/Images'
for i in os.listdir(extra_dir):
    directory = re.sub('n[0-9]+-', '', i)
    directory = directory.lower()
    for file in os.listdir(os.path.join(extra_dir, i)):
        shutil.copy(os.path.join(extra_dir, i, file), os.path.join(input_dir, 'train', directory))

# %%
def transform_train(data, label):
    im = image.imresize(data.astype('float32') / 255, 224, 224)
    auglist = image.CreateAugmenter(data_shape=(3, 224, 224), resize=0,
                                    rand_crop=True, rand_resize=True, rand_mirror=True,
                                    mean=np.array([0.485, 0.456, 0.406]), std=np.array([0.229, 0.224, 0.225]), brightness=0, contrast=0, saturation=0,
                                    hue=0, pca_noise=0, rand_gray=0.1, inter_method=2)
    for aug in auglist:
        im = aug(im)
    im = nd.transpose(im, (2, 0, 1))
    return (im, nd.array([label]).asscalar().astype('float32'))

def transform_test(data, label):
    im = image.imresize(data.astype('float32') / 255, 224, 224)
    im = nd.transpose(im, (2, 0, 1))
    return (im, nd.array([label]).asscalar().astype('float32'))

# %%
class Residual(nn.HybridBlock):
    def __init__(self, channels, same_shape=True, **kwargs):
        super(Residual, self).__init__(**kwargs)
        self.same_shape = same_shape
        with self.name_scope():
            strides = 1 if same_shape else 2
            self.conv1 = nn.Conv2D(channels, kernel_size=3, padding=1,
                                  strides=strides)
            self.bn1 = nn.BatchNorm()
            self.conv2 = nn.Conv2D(channels, kernel_size=3, padding=1)
            self.bn2 = nn.BatchNorm()
            if not same_shape:
                self.conv3 = nn.Conv2D(channels, kernel_size=1,
                                      strides=strides)

    def hybrid_forward(self, F, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.bn2(self.conv2(out))
        if not self.same_shape:
            x = self.conv3(x)
        return F.relu(out + x)


class ResNet(nn.HybridBlock):
    def __init__(self, num_classes, verbose=False, **kwargs):
        super(ResNet, self).__init__(**kwargs)
        self.verbose = verbose
        with self.name_scope():
            net = self.net = nn.HybridSequential()
            # 模块1
            net.add(nn.Conv2D(channels=32, kernel_size=3, strides=1,
                              padding=1))
            net.add(nn.BatchNorm())
            net.add(nn.Activation(activation='relu'))
            # 模块2
            for _ in range(6):
                net.add(Residual(channels=32))
            # 模块3
            net.add(Residual(channels=64, same_shape=False))
            for _ in range(4):
                net.add(Residual(channels=64))
            # 模块4
            net.add(Residual(channels=128, same_shape=False))
            for _ in range(4):
                net.add(Residual(channels=128))
            # 模块5
            net.add(nn.GlobalAvgPool2D())
            net.add(nn.Flatten())
            net.add(nn.Dense(num_classes))

    def hybrid_forward(self, F, x):
        out = x
        for i, b in enumerate(self.net):
            out = b(out)
            if self.verbose:
                print('Block %d output: %s'%(i+1, out.shape))
        return out


def get_net(ctx):
    num_outputs = 120
    net = ResNet(num_outputs)
    net.initialize(ctx=ctx, init=init.Xavier())
    return net

# %%
import datetime
import sys
sys.path.append('..')
import utils

softmax_cross_entropy = gluon.loss.SoftmaxCrossEntropyLoss()
def _get_batch(batch, ctx):
    """return data and label on ctx"""
    if isinstance(batch, mx.io.DataBatch):
        data = batch.data[0]
        label = batch.label[0]
    else:
        data, label = batch
    return (gluon.utils.split_and_load(data, ctx, even_split=False),
            gluon.utils.split_and_load(label, ctx, even_split=False),
            data.shape[0])


def accuracy(output, label):
    return nd.mean(output.argmax(axis=1)==label).asscalar()


def evaluate_accuracy(data_iterator, net, ctx=[mx.cpu()]):
    if isinstance(ctx, mx.Context):
        ctx = [ctx]
    acc = nd.array([0])
    n = 0.
    if isinstance(data_iterator, mx.io.MXDataIter):
        data_iterator.reset()
    for batch in data_iterator:
        data, label, batch_size = _get_batch(batch, ctx)
        for X, y in zip(data, label):
            acc += nd.sum(net(X).argmax(axis=1)==y).copyto(mx.cpu())
        acc.wait_to_read() # don't push too many operators into backend
        n += batch_size
    return acc.asscalar() / n

# def train(net, train_data, valid_data, num_epochs, lr, wd, ctx, lr_period, lr_decay):
#     trainer = gluon.Trainer(
#         net.collect_params(), 'sgd', {'learning_rate': lr, 'momentum': 0.9, 'wd': wd})

#     prev_time = datetime.datetime.now()
#     for epoch in range(num_epochs):
#         train_loss = 0.0
#         train_acc = 0.0
#         if epoch > 0 and epoch % lr_period == 0:
#             trainer.set_learning_rate(trainer.learning_rate * lr_decay)
#         for data, label in train_data:
#             data_list = gluon.utils.split_and_load(data, ctx, even_split=False)
#             label_list = gluon.utils.split_and_load(label, ctx, even_split=False)
# #             label = label.as_in_context(ctx)
#             with autograd.record():
#                 losses = [softmax_cross_entropy(net(X), y) for X, y in zip(data_list, label_list)]
# #                 output = net(data.as_in_context(ctx))
# #                 loss = softmax_cross_entropy(output, label)
# #             loss.backward()
#             for l in losses:
#                 l.backward()
#             train_loss += sum([l.sum().asscalar() for l in losses])
#             trainer.step(batch_size)
# #             train_loss += nd.mean(loss).asscalar()
# #             train_acc += accuracy(output, label)
#             train_acc += np.mean([accuracy(net(X), y) for X, y in zip(data_list, label_list)])
#         cur_time = datetime.datetime.now()
#         h, remainder = divmod((cur_time - prev_time).seconds, 3600)
#         m, s = divmod(remainder, 60)
#         time_str = "Time %02d:%02d:%02d" % (h, m, s)
#         if valid_data is not None:
#             valid_acc = evaluate_accuracy(valid_data, net, mx.gpu(0))
#             epoch_str = ("Epoch %d. Loss: %f, Train acc %f, Valid acc %f, "
#                          % (epoch, train_loss / len(train_data),
#                             train_acc / len(train_data), valid_acc))
#         else:
#             epoch_str = ("Epoch %d. Loss: %f, Train acc %f, "
#                          % (epoch, train_loss / len(train_data),
#                             train_acc / len(train_data)))
#         prev_time = cur_time
#         print(epoch_str + time_str + ', lr ' + str(trainer.learning_rate))

# %%
batch_size = 64
train_ds = vision.ImageFolderDataset(input_dir + 'train', flag=1,
                                     transform=transform_train)
valid_ds = vision.ImageFolderDataset(input_dir + 'valid', flag=1,
                                     transform=transform_train)
test_ds = vision.ImageFolderDataset(input_dir + 'test', flag=1,
                                     transform=transform_test)

loader = gluon.data.DataLoader
train_data = loader(train_ds, batch_size, shuffle=True, last_batch='keep')
valid_data = loader(valid_ds, batch_size, shuffle=True, last_batch='keep')
test_data = loader(test_ds, batch_size, shuffle=False, last_batch='keep')

# %%
# ctx = [mx.gpu(0), mx.gpu(1)]
# num_epochs = 300
# learning_rate = 0.1
# weight_decay = 5e-4
# lr_period = 100
# lr_decay = 0.1

# net = get_net(ctx)
# net.hybridize()
# train(net, train_data, valid_data, num_epochs, learning_rate, 
#       weight_decay, ctx, lr_period, lr_decay)

# %%
pretrained_net = models.resnet152_v1(pretrained=True)

# %%
ctx = [mx.gpu(0), mx.gpu(1)]
num_epochs = 600
learning_rate = 0.01
weight_decay = 5e-4
lr_period = 150
lr_decay = 0.1
finetune_net = models.resnet152_v1(classes=120)
finetune_net.features = pretrained_net.features
finetune_net.output.initialize(ctx=ctx[0], init=init.Xavier())

# %%
print(pretrained_net)
# Out:
# ResNetV1(
#   (features): HybridSequential(
#     (0): Conv2D(3 -> 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (1): BatchNorm(axis=1, eps=1e-05, momentum=0.9, fix_gamma=False, in_channels=64)
#     (2): Activation(relu)
#     (3): MaxPool2D(size=(3, 3), stride=(2, 2), padding=(1, 1), ceil_mode=False)
#     (4): HybridSequential(
#       (0): BottleneckV1(
#         (body): HybridSequential(
#           (0): Conv2D(64 -> 64, kernel_size=(1, 1), stride=(1, 1))
#           (1): BatchNorm(axis=1, eps=1e-05, momentum=0.9, fix_gamma=False, in_channels=64)
#           (2): Activation(relu)
#           (3): Conv2D(64 -> 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (4): BatchNorm(axis=1, eps=1e-05, momentum=0.9, fix_gamma=False, in_channels=64)
#           (5): Activation(relu)
#           (6): Conv2D(64 -> 256, kernel_size=(1, 1), stride=(1, 1))
#           (7): BatchNorm(axis=1, eps=1e-05, momentum=0.9, fix_gamma=False, in_channels=256)
#         )
#         (downsample): HybridSequential(
#           (0): Conv2D(64 -> 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm(axis=1, eps=1e-05, momentum=0.9, fix_gamma=False, in_channels=256)
#         )
#       )
#       (1): BottleneckV1(
#         (body): HybridSequential(
#           (0): Conv2D(256 -> 64, kernel_size=(1, 1), stride=(1, 1))
#           (1): BatchNorm(axis=1, eps=1e-05, momentum=0.9, fix_gamma=False, in_channels=64)
#           (2): Activation(relu)
#           (3): Conv2D(64 -> 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (4): BatchNorm(axis=1, eps=1e-05, momentum=0.9, fix_gamma=False, in_channels=64)
#           (5): Activation(relu)
#           (6): Conv2D(64 -> 256, kernel_size=(1, 1), stride=(1, 1))
#           (7): BatchNorm(axis=1, eps=1e-05, momentum=0.9, fix_gamma=False, in_channels=256)
#         )
#       )
#       (2): BottleneckV1(
#         (body): HybridSequential(
#           (0): Conv2D(256 -> 64, kernel_size=(1, 1), stride=(1, 1))
#           (1): BatchNorm(axis=1, eps=1e-05, momentum=0.9, fix_gamma=False, in_channels=64)
#           (2): Activation(relu)
#           (3): Conv2D(64 -> 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (4): BatchNorm(axis=1, eps=1e-05, momentum=0.9, fix_gamma=False, in_channels=64)
#           (5): Activation(relu)
#           (6): Conv2D(64 -> 256, kernel_size=(1, 1), stride=(1, 1))
#           (7): BatchNorm(axis=1, eps=1e-05, momentum=0.9, fix_gamma=False, in_channels=256)
#         )
#       )
#     )
#     (5): HybridSequential(
#       (0): BottleneckV1(
#         (body): HybridSequential(
#           (0): Conv2D(256 -> 128, kernel_size=(1, 1), stride=(1, 1))
#           (1): BatchNorm(axis=1, eps=1e-05, momentum=0.9, fix_gamma=False, in_channels=128)
#           (2): Activation(relu)
#           (3): Conv2D(128 -> 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (4): BatchNorm(axis=1, eps=1e-05, momentum=0.9, fix_gamma=False, in_channels=128)
#           (5): Activation(relu)
#           (6): Conv2D(128 -> 512, kernel_size=(1, 1), stride=(1, 1))
#           (7): BatchNorm(axis=1, eps=1e-05, momentum=0.9, fix_gamma=False, in_channels=512)
#         )
#         (downsample): HybridSequential(
#           (0): Conv2D(256 -> 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm(axis=1, eps=1e-05, momentum=0.9, fix_gamma=False, in_channels=512)
#         )
#       )
#       (1): BottleneckV1(
#         (body): HybridSequential(
#           (0): Conv2D(512 -> 128, kernel_size=(1, 1), stride=(1, 1))
#           (1): BatchNorm(axis=1, eps=1e-05, momentum=0.9, fix_gamma=False, in_channels=128)
#           (2): Activation(relu)
#           (3): Conv2D(128 -> 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (4): BatchNorm(axis=1, eps=1e-05, momentum=0.9, fix_gamma=False, in_channels=128)
#           (5): Activation(relu)
#           (6): Conv2D(128 -> 512, kernel_size=(1, 1), stride=(1, 1))
#           (7): BatchNorm(axis=1, eps=1e-05, momentum=0.9, fix_gamma=False, in_channels=512)
#         )
#       )
#       (2): BottleneckV1(
#         (body): HybridSequential(
#           (0): Conv2D(512 -> 128, kernel_size=(1, 1), stride=(1, 1))
#           (1): BatchNorm(axis=1, eps=1e-05, momentum=0.9, fix_gamma=False, in_channels=128)
#           (2): Activation(relu)
#           (3): Conv2D(128 -> 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (4): BatchNorm(axis=1, eps=1e-05, momentum=0.9, fix_gamma=False, in_channels=128)
#           (5): Activation(relu)
#           (6): Conv2D(128 -> 512, kernel_size=(1, 1), stride=(1, 1))
#           (7): BatchNorm(axis=1, eps=1e-05, momentum=0.9, fix_gamma=False, in_channels=512)
#         )
#       )
#       (3): BottleneckV1(
#         (body): HybridSequential(
#           (0): Conv2D(512 -> 128, kernel_size=(1, 1), stride=(1, 1))
#           (1): BatchNorm(axis=1, eps=1e-05, momentum=0.9, fix_gamma=False, in_channels=128)
#           (2): Activation(relu)
#           (3): Conv2D(128 -> 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (4): BatchNorm(axis=1, eps=1e-05, momentum=0.9, fix_gamma=False, in_channels=128)
#           (5): Activation(relu)
#           (6): Conv2D(128 -> 512, kernel_size=(1, 1), stride=(1, 1))
#           (7): BatchNorm(axis=1, eps=1e-05, momentum=0.9, fix_gamma=False, in_channels=512)
#         )
#       )
#       (4): BottleneckV1(
#         (body): HybridSequential(
#           (0): Conv2D(512 -> 128, kernel_size=(1, 1), stride=(1, 1))
#           (1): BatchNorm(axis=1, eps=1e-05, momentum=0.9, fix_gamma=False, in_channels=128)
#           (2): Activation(relu)
#           (3): Conv2D(128 -> 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (4): BatchNorm(axis=1, eps=1e-05, momentum=0.9, fix_gamma=False, in_channels=128)
#           (5): Activation(relu)
#           (6): Conv2D(128 -> 512, kernel_size=(1, 1), stride=(1, 1))
#           (7): BatchNorm(axis=1, eps=1e-05, momentum=0.9, fix_gamma=False, in_channels=512)
#         )
#       )
#       (5): BottleneckV1(
#         (body): HybridSequential(
#           (0): Conv2D(512 -> 128, kernel_size=(1, 1), stride=(1, 1))
#           (1): BatchNorm(axis=1, eps=1e-05, momentum=0.9, fix_gamma=False, in_channels=128)
#           (2): Activation(relu)
#           (3): Conv2D(128 -> 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (4): BatchNorm(axis=1, eps=1e-05, momentum=0.9, fix_gamma=False, in_channels=128)
#           (5): Activation(relu)
#           (6): Conv2D(128 -> 512, kernel_size=(1, 1), stride=(1, 1))
#           (7): BatchNorm(axis=1, eps=1e-05, momentum=0.9, fix_gamma=False, in_channels=512)
#         )
#       )
#       (6): BottleneckV1(
#         (body): HybridSequential(
#           (0): Conv2D(512 -> 128, kernel_size=(1, 1), stride=(1, 1))
#           (1): BatchNorm(axis=1, eps=1e-05, momentum=0.9, fix_gamma=False, in_channels=128)
#           (2): Activation(relu)
#           (3): Conv2D(128 -> 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (4): BatchNorm(axis=1, eps=1e-05, momentum=0.9, fix_gamma=False, in_channels=128)
#           (5): Activation(relu)
#           (6): Conv2D(128 -> 512, kernel_size=(1, 1), stride=(1, 1))
#           (7): BatchNorm(axis=1, eps=1e-05, momentum=0.9, fix_gamma=False, in_channels=512)
#         )
#       )
#       (7): BottleneckV1(
#         (body): HybridSequential(
#           (0): Conv2D(512 -> 128, kernel_size=(1, 1), stride=(1, 1))
#           (1): BatchNorm(axis=1, eps=1e-05, momentum=0.9, fix_gamma=False, in_channels=128)
#           (2): Activation(relu)
#           (3): Conv2D(128 -> 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (4): BatchNorm(axis=1, eps=1e-05, momentum=0.9, fix_gamma=False, in_channels=128)
#           (5): Activation(relu)
#           (6): Conv2D(128 -> 512, kernel_size=(1, 1), stride=(1, 1))
#           (7): BatchNorm(axis=1, eps=1e-05, momentum=0.9, fix_gamma=False, in_channels=512)
#         )
#       )
#     )
#     (6): HybridSequential(
#       (0): BottleneckV1(
#         (body): HybridSequential(
#           (0): Conv2D(512 -> 256, kernel_size=(1, 1), stride=(1, 1))
#           (1): BatchNorm(axis=1, eps=1e-05, momentum=0.9, fix_gamma=False, in_channels=256)
#           (2): Activation(relu)
#           (3): Conv2D(256 -> 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (4): BatchNorm(axis=1, eps=1e-05, momentum=0.9, fix_gamma=False, in_channels=256)
#           (5): Activation(relu)
#           (6): Conv2D(256 -> 1024, kernel_size=(1, 1), stride=(1, 1))
#           (7): BatchNorm(axis=1, eps=1e-05, momentum=0.9, fix_gamma=False, in_channels=1024)
#         )
#         (downsample): HybridSequential(
#           (0): Conv2D(512 -> 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm(axis=1, eps=1e-05, momentum=0.9, fix_gamma=False, in_channels=1024)
#         )
#       )
#       (1): BottleneckV1(
#         (body): HybridSequential(
#           (0): Conv2D(1024 -> 256, kernel_size=(1, 1), stride=(1, 1))
#           (1): BatchNorm(axis=1, eps=1e-05, momentum=0.9, fix_gamma=False, in_channels=256)
#           (2): Activation(relu)
#           (3): Conv2D(256 -> 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (4): BatchNorm(axis=1, eps=1e-05, momentum=0.9, fix_gamma=False, in_channels=256)
#           (5): Activation(relu)
#           (6): Conv2D(256 -> 1024, kernel_size=(1, 1), stride=(1, 1))
#           (7): BatchNorm(axis=1, eps=1e-05, momentum=0.9, fix_gamma=False, in_channels=1024)
#         )
#       )
#       (2): BottleneckV1(
#         (body): HybridSequential(
#           (0): Conv2D(1024 -> 256, kernel_size=(1, 1), stride=(1, 1))
#           (1): BatchNorm(axis=1, eps=1e-05, momentum=0.9, fix_gamma=False, in_channels=256)
#           (2): Activation(relu)
#           (3): Conv2D(256 -> 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (4): BatchNorm(axis=1, eps=1e-05, momentum=0.9, fix_gamma=False, in_channels=256)
#           (5): Activation(relu)
#           (6): Conv2D(256 -> 1024, kernel_size=(1, 1), stride=(1, 1))
#           (7): BatchNorm(axis=1, eps=1e-05, momentum=0.9, fix_gamma=False, in_channels=1024)
#         )
#       )
#       (3): BottleneckV1(
#         (body): HybridSequential(
#           (0): Conv2D(1024 -> 256, kernel_size=(1, 1), stride=(1, 1))
#           (1): BatchNorm(axis=1, eps=1e-05, momentum=0.9, fix_gamma=False, in_channels=256)
#           (2): Activation(relu)
#           (3): Conv2D(256 -> 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (4): BatchNorm(axis=1, eps=1e-05, momentum=0.9, fix_gamma=False, in_channels=256)
#           (5): Activation(relu)
#           (6): Conv2D(256 -> 1024, kernel_size=(1, 1), stride=(1, 1))
#           (7): BatchNorm(axis=1, eps=1e-05, momentum=0.9, fix_gamma=False, in_channels=1024)
#         )
#       )
#       (4): BottleneckV1(
#         (body): HybridSequential(
#           (0): Conv2D(1024 -> 256, kernel_size=(1, 1), stride=(1, 1))
#           (1): BatchNorm(axis=1, eps=1e-05, momentum=0.9, fix_gamma=False, in_channels=256)
#           (2): Activation(relu)
#           (3): Conv2D(256 -> 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (4): BatchNorm(axis=1, eps=1e-05, momentum=0.9, fix_gamma=False, in_channels=256)
#           (5): Activation(relu)
#           (6): Conv2D(256 -> 1024, kernel_size=(1, 1), stride=(1, 1))
#           (7): BatchNorm(axis=1, eps=1e-05, momentum=0.9, fix_gamma=False, in_channels=1024)
#         )
#       )
#       (5): BottleneckV1(
#         (body): HybridSequential(
#           (0): Conv2D(1024 -> 256, kernel_size=(1, 1), stride=(1, 1))
#           (1): BatchNorm(axis=1, eps=1e-05, momentum=0.9, fix_gamma=False, in_channels=256)
#           (2): Activation(relu)
#           (3): Conv2D(256 -> 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (4): BatchNorm(axis=1, eps=1e-05, momentum=0.9, fix_gamma=False, in_channels=256)
#           (5): Activation(relu)
#           (6): Conv2D(256 -> 1024, kernel_size=(1, 1), stride=(1, 1))
#           (7): BatchNorm(axis=1, eps=1e-05, momentum=0.9, fix_gamma=False, in_channels=1024)
#         )
#       )
#       (6): BottleneckV1(
#         (body): HybridSequential(
#           (0): Conv2D(1024 -> 256, kernel_size=(1, 1), stride=(1, 1))
#           (1): BatchNorm(axis=1, eps=1e-05, momentum=0.9, fix_gamma=False, in_channels=256)
#           (2): Activation(relu)
#           (3): Conv2D(256 -> 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (4): BatchNorm(axis=1, eps=1e-05, momentum=0.9, fix_gamma=False, in_channels=256)
#           (5): Activation(relu)
#           (6): Conv2D(256 -> 1024, kernel_size=(1, 1), stride=(1, 1))
#           (7): BatchNorm(axis=1, eps=1e-05, momentum=0.9, fix_gamma=False, in_channels=1024)
#         )
#       )
#       (7): BottleneckV1(
#         (body): HybridSequential(
#           (0): Conv2D(1024 -> 256, kernel_size=(1, 1), stride=(1, 1))
#           (1): BatchNorm(axis=1, eps=1e-05, momentum=0.9, fix_gamma=False, in_channels=256)
#           (2): Activation(relu)
#           (3): Conv2D(256 -> 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (4): BatchNorm(axis=1, eps=1e-05, momentum=0.9, fix_gamma=False, in_channels=256)
#           (5): Activation(relu)
#           (6): Conv2D(256 -> 1024, kernel_size=(1, 1), stride=(1, 1))
#           (7): BatchNorm(axis=1, eps=1e-05, momentum=0.9, fix_gamma=False, in_channels=1024)
#         )
#       )
#       (8): BottleneckV1(
#         (body): HybridSequential(
#           (0): Conv2D(1024 -> 256, kernel_size=(1, 1), stride=(1, 1))
#           (1): BatchNorm(axis=1, eps=1e-05, momentum=0.9, fix_gamma=False, in_channels=256)
#           (2): Activation(relu)
#           (3): Conv2D(256 -> 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (4): BatchNorm(axis=1, eps=1e-05, momentum=0.9, fix_gamma=False, in_channels=256)
#           (5): Activation(relu)
#           (6): Conv2D(256 -> 1024, kernel_size=(1, 1), stride=(1, 1))
#           (7): BatchNorm(axis=1, eps=1e-05, momentum=0.9, fix_gamma=False, in_channels=1024)
#         )
#       )
#       (9): BottleneckV1(
#         (body): HybridSequential(
#           (0): Conv2D(1024 -> 256, kernel_size=(1, 1), stride=(1, 1))
#           (1): BatchNorm(axis=1, eps=1e-05, momentum=0.9, fix_gamma=False, in_channels=256)
#           (2): Activation(relu)
#           (3): Conv2D(256 -> 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (4): BatchNorm(axis=1, eps=1e-05, momentum=0.9, fix_gamma=False, in_channels=256)
#           (5): Activation(relu)
#           (6): Conv2D(256 -> 1024, kernel_size=(1, 1), stride=(1, 1))
#           (7): BatchNorm(axis=1, eps=1e-05, momentum=0.9, fix_gamma=False, in_channels=1024)
#         )
#       )
#       (10): BottleneckV1(
#         (body): HybridSequential(
#           (0): Conv2D(1024 -> 256, kernel_size=(1, 1), stride=(1, 1))
#           (1): BatchNorm(axis=1, eps=1e-05, momentum=0.9, fix_gamma=False, in_channels=256)
#           (2): Activation(relu)
#           (3): Conv2D(256 -> 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (4): BatchNorm(axis=1, eps=1e-05, momentum=0.9, fix_gamma=False, in_channels=256)
#           (5): Activation(relu)
#           (6): Conv2D(256 -> 1024, kernel_size=(1, 1), stride=(1, 1))
#           (7): BatchNorm(axis=1, eps=1e-05, momentum=0.9, fix_gamma=False, in_channels=1024)
#         )
#       )
#       (11): BottleneckV1(
#         (body): HybridSequential(
#           (0): Conv2D(1024 -> 256, kernel_size=(1, 1), stride=(1, 1))
#           (1): BatchNorm(axis=1, eps=1e-05, momentum=0.9, fix_gamma=False, in_channels=256)
#           (2): Activation(relu)
#           (3): Conv2D(256 -> 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (4): BatchNorm(axis=1, eps=1e-05, momentum=0.9, fix_gamma=False, in_channels=256)
#           (5): Activation(relu)
#           (6): Conv2D(256 -> 1024, kernel_size=(1, 1), stride=(1, 1))
#           (7): BatchNorm(axis=1, eps=1e-05, momentum=0.9, fix_gamma=False, in_channels=1024)
#         )
#       )
#       (12): BottleneckV1(
#         (body): HybridSequential(
#           (0): Conv2D(1024 -> 256, kernel_size=(1, 1), stride=(1, 1))
#           (1): BatchNorm(axis=1, eps=1e-05, momentum=0.9, fix_gamma=False, in_channels=256)
#           (2): Activation(relu)
#           (3): Conv2D(256 -> 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (4): BatchNorm(axis=1, eps=1e-05, momentum=0.9, fix_gamma=False, in_channels=256)
#           (5): Activation(relu)
#           (6): Conv2D(256 -> 1024, kernel_size=(1, 1), stride=(1, 1))
#           (7): BatchNorm(axis=1, eps=1e-05, momentum=0.9, fix_gamma=False, in_channels=1024)
#         )
#       )
#       (13): BottleneckV1(
#         (body): HybridSequential(
#           (0): Conv2D(1024 -> 256, kernel_size=(1, 1), stride=(1, 1))
#           (1): BatchNorm(axis=1, eps=1e-05, momentum=0.9, fix_gamma=False, in_channels=256)
#           (2): Activation(relu)
#           (3): Conv2D(256 -> 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (4): BatchNorm(axis=1, eps=1e-05, momentum=0.9, fix_gamma=False, in_channels=256)
#           (5): Activation(relu)
#           (6): Conv2D(256 -> 1024, kernel_size=(1, 1), stride=(1, 1))
#           (7): BatchNorm(axis=1, eps=1e-05, momentum=0.9, fix_gamma=False, in_channels=1024)
#         )
#       )
#       (14): BottleneckV1(
#         (body): HybridSequential(
#           (0): Conv2D(1024 -> 256, kernel_size=(1, 1), stride=(1, 1))
#           (1): BatchNorm(axis=1, eps=1e-05, momentum=0.9, fix_gamma=False, in_channels=256)
#           (2): Activation(relu)
#           (3): Conv2D(256 -> 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (4): BatchNorm(axis=1, eps=1e-05, momentum=0.9, fix_gamma=False, in_channels=256)
#           (5): Activation(relu)
#           (6): Conv2D(256 -> 1024, kernel_size=(1, 1), stride=(1, 1))
#           (7): BatchNorm(axis=1, eps=1e-05, momentum=0.9, fix_gamma=False, in_channels=1024)
#         )
#       )
#       (15): BottleneckV1(
#         (body): HybridSequential(
#           (0): Conv2D(1024 -> 256, kernel_size=(1, 1), stride=(1, 1))
#           (1): BatchNorm(axis=1, eps=1e-05, momentum=0.9, fix_gamma=False, in_channels=256)
#           (2): Activation(relu)
#           (3): Conv2D(256 -> 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (4): BatchNorm(axis=1, eps=1e-05, momentum=0.9, fix_gamma=False, in_channels=256)
#           (5): Activation(relu)
#           (6): Conv2D(256 -> 1024, kernel_size=(1, 1), stride=(1, 1))
#           (7): BatchNorm(axis=1, eps=1e-05, momentum=0.9, fix_gamma=False, in_channels=1024)
#         )
#       )
#       (16): BottleneckV1(
#         (body): HybridSequential(
#           (0): Conv2D(1024 -> 256, kernel_size=(1, 1), stride=(1, 1))
#           (1): BatchNorm(axis=1, eps=1e-05, momentum=0.9, fix_gamma=False, in_channels=256)
#           (2): Activation(relu)
#           (3): Conv2D(256 -> 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (4): BatchNorm(axis=1, eps=1e-05, momentum=0.9, fix_gamma=False, in_channels=256)
#           (5): Activation(relu)
#           (6): Conv2D(256 -> 1024, kernel_size=(1, 1), stride=(1, 1))
#           (7): BatchNorm(axis=1, eps=1e-05, momentum=0.9, fix_gamma=False, in_channels=1024)
#         )
#       )
#       (17): BottleneckV1(
#         (body): HybridSequential(
#           (0): Conv2D(1024 -> 256, kernel_size=(1, 1), stride=(1, 1))
#           (1): BatchNorm(axis=1, eps=1e-05, momentum=0.9, fix_gamma=False, in_channels=256)
#           (2): Activation(relu)
#           (3): Conv2D(256 -> 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (4): BatchNorm(axis=1, eps=1e-05, momentum=0.9, fix_gamma=False, in_channels=256)
#           (5): Activation(relu)
#           (6): Conv2D(256 -> 1024, kernel_size=(1, 1), stride=(1, 1))
#           (7): BatchNorm(axis=1, eps=1e-05, momentum=0.9, fix_gamma=False, in_channels=1024)
#         )
#       )
#       (18): BottleneckV1(
#         (body): HybridSequential(
#           (0): Conv2D(1024 -> 256, kernel_size=(1, 1), stride=(1, 1))
#           (1): BatchNorm(axis=1, eps=1e-05, momentum=0.9, fix_gamma=False, in_channels=256)
#           (2): Activation(relu)
#           (3): Conv2D(256 -> 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (4): BatchNorm(axis=1, eps=1e-05, momentum=0.9, fix_gamma=False, in_channels=256)
#           (5): Activation(relu)
#           (6): Conv2D(256 -> 1024, kernel_size=(1, 1), stride=(1, 1))
#           (7): BatchNorm(axis=1, eps=1e-05, momentum=0.9, fix_gamma=False, in_channels=1024)
#         )
#       )
#       (19): BottleneckV1(
#         (body): HybridSequential(
#           (0): Conv2D(1024 -> 256, kernel_size=(1, 1), stride=(1, 1))
#           (1): BatchNorm(axis=1, eps=1e-05, momentum=0.9, fix_gamma=False, in_channels=256)
#           (2): Activation(relu)
#           (3): Conv2D(256 -> 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (4): BatchNorm(axis=1, eps=1e-05, momentum=0.9, fix_gamma=False, in_channels=256)
#           (5): Activation(relu)
#           (6): Conv2D(256 -> 1024, kernel_size=(1, 1), stride=(1, 1))
#           (7): BatchNorm(axis=1, eps=1e-05, momentum=0.9, fix_gamma=False, in_channels=1024)
#         )
#       )
#       (20): BottleneckV1(
#         (body): HybridSequential(
#           (0): Conv2D(1024 -> 256, kernel_size=(1, 1), stride=(1, 1))
#           (1): BatchNorm(axis=1, eps=1e-05, momentum=0.9, fix_gamma=False, in_channels=256)
#           (2): Activation(relu)
#           (3): Conv2D(256 -> 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (4): BatchNorm(axis=1, eps=1e-05, momentum=0.9, fix_gamma=False, in_channels=256)
#           (5): Activation(relu)
#           (6): Conv2D(256 -> 1024, kernel_size=(1, 1), stride=(1, 1))
#           (7): BatchNorm(axis=1, eps=1e-05, momentum=0.9, fix_gamma=False, in_channels=1024)
#         )
#       )
#       (21): BottleneckV1(
#         (body): HybridSequential(
#           (0): Conv2D(1024 -> 256, kernel_size=(1, 1), stride=(1, 1))
#           (1): BatchNorm(axis=1, eps=1e-05, momentum=0.9, fix_gamma=False, in_channels=256)
#           (2): Activation(relu)
#           (3): Conv2D(256 -> 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (4): BatchNorm(axis=1, eps=1e-05, momentum=0.9, fix_gamma=False, in_channels=256)
#           (5): Activation(relu)
#           (6): Conv2D(256 -> 1024, kernel_size=(1, 1), stride=(1, 1))
#           (7): BatchNorm(axis=1, eps=1e-05, momentum=0.9, fix_gamma=False, in_channels=1024)
#         )
#       )
#       (22): BottleneckV1(
#         (body): HybridSequential(
#           (0): Conv2D(1024 -> 256, kernel_size=(1, 1), stride=(1, 1))
#           (1): BatchNorm(axis=1, eps=1e-05, momentum=0.9, fix_gamma=False, in_channels=256)
#           (2): Activation(relu)
#           (3): Conv2D(256 -> 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (4): BatchNorm(axis=1, eps=1e-05, momentum=0.9, fix_gamma=False, in_channels=256)
#           (5): Activation(relu)
#           (6): Conv2D(256 -> 1024, kernel_size=(1, 1), stride=(1, 1))
#           (7): BatchNorm(axis=1, eps=1e-05, momentum=0.9, fix_gamma=False, in_channels=1024)
#         )
#       )
#       (23): BottleneckV1(
#         (body): HybridSequential(
#           (0): Conv2D(1024 -> 256, kernel_size=(1, 1), stride=(1, 1))
#           (1): BatchNorm(axis=1, eps=1e-05, momentum=0.9, fix_gamma=False, in_channels=256)
#           (2): Activation(relu)
#           (3): Conv2D(256 -> 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (4): BatchNorm(axis=1, eps=1e-05, momentum=0.9, fix_gamma=False, in_channels=256)
#           (5): Activation(relu)
#           (6): Conv2D(256 -> 1024, kernel_size=(1, 1), stride=(1, 1))
#           (7): BatchNorm(axis=1, eps=1e-05, momentum=0.9, fix_gamma=False, in_channels=1024)
#         )
#       )
#       (24): BottleneckV1(
#         (body): HybridSequential(
#           (0): Conv2D(1024 -> 256, kernel_size=(1, 1), stride=(1, 1))
#           (1): BatchNorm(axis=1, eps=1e-05, momentum=0.9, fix_gamma=False, in_channels=256)
#           (2): Activation(relu)
#           (3): Conv2D(256 -> 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (4): BatchNorm(axis=1, eps=1e-05, momentum=0.9, fix_gamma=False, in_channels=256)
#           (5): Activation(relu)
#           (6): Conv2D(256 -> 1024, kernel_size=(1, 1), stride=(1, 1))
#           (7): BatchNorm(axis=1, eps=1e-05, momentum=0.9, fix_gamma=False, in_channels=1024)
#         )
#       )
#       (25): BottleneckV1(
#         (body): HybridSequential(
#           (0): Conv2D(1024 -> 256, kernel_size=(1, 1), stride=(1, 1))
#           (1): BatchNorm(axis=1, eps=1e-05, momentum=0.9, fix_gamma=False, in_channels=256)
#           (2): Activation(relu)
#           (3): Conv2D(256 -> 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (4): BatchNorm(axis=1, eps=1e-05, momentum=0.9, fix_gamma=False, in_channels=256)
#           (5): Activation(relu)
#           (6): Conv2D(256 -> 1024, kernel_size=(1, 1), stride=(1, 1))
#           (7): BatchNorm(axis=1, eps=1e-05, momentum=0.9, fix_gamma=False, in_channels=1024)
#         )
#       )
#       (26): BottleneckV1(
#         (body): HybridSequential(
#           (0): Conv2D(1024 -> 256, kernel_size=(1, 1), stride=(1, 1))
#           (1): BatchNorm(axis=1, eps=1e-05, momentum=0.9, fix_gamma=False, in_channels=256)
#           (2): Activation(relu)
#           (3): Conv2D(256 -> 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (4): BatchNorm(axis=1, eps=1e-05, momentum=0.9, fix_gamma=False, in_channels=256)
#           (5): Activation(relu)
#           (6): Conv2D(256 -> 1024, kernel_size=(1, 1), stride=(1, 1))
#           (7): BatchNorm(axis=1, eps=1e-05, momentum=0.9, fix_gamma=False, in_channels=1024)
#         )
#       )
#       (27): BottleneckV1(
#         (body): HybridSequential(
#           (0): Conv2D(1024 -> 256, kernel_size=(1, 1), stride=(1, 1))
#           (1): BatchNorm(axis=1, eps=1e-05, momentum=0.9, fix_gamma=False, in_channels=256)
#           (2): Activation(relu)
#           (3): Conv2D(256 -> 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (4): BatchNorm(axis=1, eps=1e-05, momentum=0.9, fix_gamma=False, in_channels=256)
#           (5): Activation(relu)
#           (6): Conv2D(256 -> 1024, kernel_size=(1, 1), stride=(1, 1))
#           (7): BatchNorm(axis=1, eps=1e-05, momentum=0.9, fix_gamma=False, in_channels=1024)
#         )
#       )
#       (28): BottleneckV1(
#         (body): HybridSequential(
#           (0): Conv2D(1024 -> 256, kernel_size=(1, 1), stride=(1, 1))
#           (1): BatchNorm(axis=1, eps=1e-05, momentum=0.9, fix_gamma=False, in_channels=256)
#           (2): Activation(relu)
#           (3): Conv2D(256 -> 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (4): BatchNorm(axis=1, eps=1e-05, momentum=0.9, fix_gamma=False, in_channels=256)
#           (5): Activation(relu)
#           (6): Conv2D(256 -> 1024, kernel_size=(1, 1), stride=(1, 1))
#           (7): BatchNorm(axis=1, eps=1e-05, momentum=0.9, fix_gamma=False, in_channels=1024)
#         )
#       )
#       (29): BottleneckV1(
#         (body): HybridSequential(
#           (0): Conv2D(1024 -> 256, kernel_size=(1, 1), stride=(1, 1))
#           (1): BatchNorm(axis=1, eps=1e-05, momentum=0.9, fix_gamma=False, in_channels=256)
#           (2): Activation(relu)
#           (3): Conv2D(256 -> 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (4): BatchNorm(axis=1, eps=1e-05, momentum=0.9, fix_gamma=False, in_channels=256)
#           (5): Activation(relu)
#           (6): Conv2D(256 -> 1024, kernel_size=(1, 1), stride=(1, 1))
#           (7): BatchNorm(axis=1, eps=1e-05, momentum=0.9, fix_gamma=False, in_channels=1024)
#         )
#       )
#       (30): BottleneckV1(
#         (body): HybridSequential(
#           (0): Conv2D(1024 -> 256, kernel_size=(1, 1), stride=(1, 1))
#           (1): BatchNorm(axis=1, eps=1e-05, momentum=0.9, fix_gamma=False, in_channels=256)
#           (2): Activation(relu)
#           (3): Conv2D(256 -> 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (4): BatchNorm(axis=1, eps=1e-05, momentum=0.9, fix_gamma=False, in_channels=256)
#           (5): Activation(relu)
#           (6): Conv2D(256 -> 1024, kernel_size=(1, 1), stride=(1, 1))
#           (7): BatchNorm(axis=1, eps=1e-05, momentum=0.9, fix_gamma=False, in_channels=1024)
#         )
#       )
#       (31): BottleneckV1(
#         (body): HybridSequential(
#           (0): Conv2D(1024 -> 256, kernel_size=(1, 1), stride=(1, 1))
#           (1): BatchNorm(axis=1, eps=1e-05, momentum=0.9, fix_gamma=False, in_channels=256)
#           (2): Activation(relu)
#           (3): Conv2D(256 -> 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (4): BatchNorm(axis=1, eps=1e-05, momentum=0.9, fix_gamma=False, in_channels=256)
#           (5): Activation(relu)
#           (6): Conv2D(256 -> 1024, kernel_size=(1, 1), stride=(1, 1))
#           (7): BatchNorm(axis=1, eps=1e-05, momentum=0.9, fix_gamma=False, in_channels=1024)
#         )
#       )
#       (32): BottleneckV1(
#         (body): HybridSequential(
#           (0): Conv2D(1024 -> 256, kernel_size=(1, 1), stride=(1, 1))
#           (1): BatchNorm(axis=1, eps=1e-05, momentum=0.9, fix_gamma=False, in_channels=256)
#           (2): Activation(relu)
#           (3): Conv2D(256 -> 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (4): BatchNorm(axis=1, eps=1e-05, momentum=0.9, fix_gamma=False, in_channels=256)
#           (5): Activation(relu)
#           (6): Conv2D(256 -> 1024, kernel_size=(1, 1), stride=(1, 1))
#           (7): BatchNorm(axis=1, eps=1e-05, momentum=0.9, fix_gamma=False, in_channels=1024)
#         )
#       )
#       (33): BottleneckV1(
#         (body): HybridSequential(
#           (0): Conv2D(1024 -> 256, kernel_size=(1, 1), stride=(1, 1))
#           (1): BatchNorm(axis=1, eps=1e-05, momentum=0.9, fix_gamma=False, in_channels=256)
#           (2): Activation(relu)
#           (3): Conv2D(256 -> 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (4): BatchNorm(axis=1, eps=1e-05, momentum=0.9, fix_gamma=False, in_channels=256)
#           (5): Activation(relu)
#           (6): Conv2D(256 -> 1024, kernel_size=(1, 1), stride=(1, 1))
#           (7): BatchNorm(axis=1, eps=1e-05, momentum=0.9, fix_gamma=False, in_channels=1024)
#         )
#       )
#       (34): BottleneckV1(
#         (body): HybridSequential(
#           (0): Conv2D(1024 -> 256, kernel_size=(1, 1), stride=(1, 1))
#           (1): BatchNorm(axis=1, eps=1e-05, momentum=0.9, fix_gamma=False, in_channels=256)
#           (2): Activation(relu)
#           (3): Conv2D(256 -> 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (4): BatchNorm(axis=1, eps=1e-05, momentum=0.9, fix_gamma=False, in_channels=256)
#           (5): Activation(relu)
#           (6): Conv2D(256 -> 1024, kernel_size=(1, 1), stride=(1, 1))
#           (7): BatchNorm(axis=1, eps=1e-05, momentum=0.9, fix_gamma=False, in_channels=1024)
#         )
#       )
#       (35): BottleneckV1(
#         (body): HybridSequential(
#           (0): Conv2D(1024 -> 256, kernel_size=(1, 1), stride=(1, 1))
#           (1): BatchNorm(axis=1, eps=1e-05, momentum=0.9, fix_gamma=False, in_channels=256)
#           (2): Activation(relu)
#           (3): Conv2D(256 -> 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (4): BatchNorm(axis=1, eps=1e-05, momentum=0.9, fix_gamma=False, in_channels=256)
#           (5): Activation(relu)
#           (6): Conv2D(256 -> 1024, kernel_size=(1, 1), stride=(1, 1))
#           (7): BatchNorm(axis=1, eps=1e-05, momentum=0.9, fix_gamma=False, in_channels=1024)
#         )
#       )
#     )
#     (7): HybridSequential(
#       (0): BottleneckV1(
#         (body): HybridSequential(
#           (0): Conv2D(1024 -> 512, kernel_size=(1, 1), stride=(1, 1))
#           (1): BatchNorm(axis=1, eps=1e-05, momentum=0.9, fix_gamma=False, in_channels=512)
#           (2): Activation(relu)
#           (3): Conv2D(512 -> 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (4): BatchNorm(axis=1, eps=1e-05, momentum=0.9, fix_gamma=False, in_channels=512)
#           (5): Activation(relu)
#           (6): Conv2D(512 -> 2048, kernel_size=(1, 1), stride=(1, 1))
#           (7): BatchNorm(axis=1, eps=1e-05, momentum=0.9, fix_gamma=False, in_channels=2048)
#         )
#         (downsample): HybridSequential(
#           (0): Conv2D(1024 -> 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm(axis=1, eps=1e-05, momentum=0.9, fix_gamma=False, in_channels=2048)
#         )
#       )
#       (1): BottleneckV1(
#         (body): HybridSequential(
#           (0): Conv2D(2048 -> 512, kernel_size=(1, 1), stride=(1, 1))
#           (1): BatchNorm(axis=1, eps=1e-05, momentum=0.9, fix_gamma=False, in_channels=512)
#           (2): Activation(relu)
#           (3): Conv2D(512 -> 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (4): BatchNorm(axis=1, eps=1e-05, momentum=0.9, fix_gamma=False, in_channels=512)
#           (5): Activation(relu)
#           (6): Conv2D(512 -> 2048, kernel_size=(1, 1), stride=(1, 1))
#           (7): BatchNorm(axis=1, eps=1e-05, momentum=0.9, fix_gamma=False, in_channels=2048)
#         )
#       )
#       (2): BottleneckV1(
#         (body): HybridSequential(
#           (0): Conv2D(2048 -> 512, kernel_size=(1, 1), stride=(1, 1))
#           (1): BatchNorm(axis=1, eps=1e-05, momentum=0.9, fix_gamma=False, in_channels=512)
#           (2): Activation(relu)
#           (3): Conv2D(512 -> 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (4): BatchNorm(axis=1, eps=1e-05, momentum=0.9, fix_gamma=False, in_channels=512)
#           (5): Activation(relu)
#           (6): Conv2D(512 -> 2048, kernel_size=(1, 1), stride=(1, 1))
#           (7): BatchNorm(axis=1, eps=1e-05, momentum=0.9, fix_gamma=False, in_channels=2048)
#         )
#       )
#     )
#     (8): GlobalAvgPool2D(size=(1, 1), stride=(1, 1), padding=(0, 0), ceil_mode=True)
#   )
#   (output): Dense(2048 -> 1000, linear)
# )

# %%
def util_train(train_data, test_data, net, loss, trainer, ctx, num_epochs, lr_period, lr_decay, print_batches=None):
    """Train a network"""
    total_times = 0
    print("Start training on ", ctx)
    if isinstance(ctx, mx.Context):
        ctx = [ctx]
    for epoch in range(num_epochs):
        if epoch > 0 and epoch % lr_period == 0:
            trainer.set_learning_rate(trainer.learning_rate * lr_decay)
        train_loss, train_acc, n, m_all = 0.0, 0.0, 0.0, 0.0
        if isinstance(train_data, mx.io.MXDataIter):
            train_data.reset()
        start = time()
        for i, batch in enumerate(train_data):
            data, label, batch_size = _get_batch(batch, ctx)
            losses = []
            with autograd.record():
                outputs = [net(X) for X in data]
                losses = [loss(yhat, y) for yhat, y in zip(outputs, label)]
            for l in losses:
                l.backward()
            train_acc += sum([(yhat.argmax(axis=1)==y).sum().asscalar()
                              for yhat, y in zip(outputs, label)])
            train_loss += sum([l.sum().asscalar() for l in losses])
            trainer.step(batch_size)
            n += batch_size
            m_all += sum([y.size for y in label])
            if print_batches and (i+1) % print_batches == 0:
                print("Batch %d. Loss: %f, Train acc %f" % (
                    n, train_loss/n, train_acc/m_all
                ))

        test_acc = evaluate_accuracy(test_data, net, ctx)
        duration = time() - start
        total_times += duration
        h, remainder = divmod(total_times, 3600)
        m, s = divmod(remainder, 60)
        time_str = "%02d:%02d:%02d" % (h, m, s)
        print("Epoch %d. Loss: %f, Train acc %f, Valid acc %f, Time %.1f sec, Total time %s, lr %s" % (
            epoch, train_loss/n, train_acc/m_all, test_acc, duration, time_str, str(trainer.learning_rate)
        ))

# %%
def train(net, ctx, epochs=num_epochs, learning_rate=learning_rate, wd=weight_decay):
    # 确保net的初始化在ctx上
    net.collect_params().reset_ctx(ctx)
    net.hybridize()
    loss = gluon.loss.SoftmaxCrossEntropyLoss()
    # 训练
    trainer = gluon.Trainer(net.collect_params(), 'sgd', {
        'learning_rate': learning_rate, 'wd': wd})
    count = 0
    for _, i in finetune_net.features.collect_params().items():
        count += 1
        i.lr_mult = learning_rate
        if count >= 820:
            i.lr_mult = learning_rate * 10
    util_train(train_data, valid_data, net, loss, trainer, ctx, epochs, lr_period, lr_decay)

# %%
train(finetune_net, ctx)
# Out:
# Start training on  [gpu(0), gpu(1)]
# Epoch 0. Loss: 4.129219, Train acc 0.156061, Valid acc 0.344912, Time 553.4 sec, Total time 00:09:13, lr 0.01
# Epoch 1. Loss: 2.665453, Train acc 0.450553, Valid acc 0.533757, Time 543.7 sec, Total time 00:18:17, lr 0.01
# Epoch 2. Loss: 1.959670, Train acc 0.562974, Valid acc 0.619374, Time 540.3 sec, Total time 00:27:17, lr 0.01
# Epoch 3. Loss: 1.635342, Train acc 0.607970, Valid acc 0.602740, Time 543.8 sec, Total time 00:36:21, lr 0.01
# Epoch 4. Loss: 1.457243, Train acc 0.637144, Valid acc 0.654110, Time 545.5 sec, Total time 00:45:26, lr 0.01
# Epoch 5. Loss: 1.345149, Train acc 0.656617, Valid acc 0.681018, Time 545.5 sec, Total time 00:54:32, lr 0.01
# Epoch 6. Loss: 1.283257, Train acc 0.663537, Valid acc 0.698630, Time 543.1 sec, Total time 01:03:35, lr 0.01
# Epoch 7. Loss: 1.211972, Train acc 0.679220, Valid acc 0.681996, Time 546.5 sec, Total time 01:12:41, lr 0.01
# Epoch 8. Loss: 1.181558, Train acc 0.683149, Valid acc 0.684932, Time 541.9 sec, Total time 01:21:43, lr 0.01
# Epoch 9. Loss: 1.128760, Train acc 0.695424, Valid acc 0.716732, Time 547.1 sec, Total time 01:30:50, lr 0.01
# Epoch 10. Loss: 1.100158, Train acc 0.702274, Valid acc 0.706458, Time 545.4 sec, Total time 01:39:56, lr 0.01
# Epoch 11. Loss: 1.077124, Train acc 0.709090, Valid acc 0.710372, Time 545.2 sec, Total time 01:49:01, lr 0.01
# Epoch 12. Loss: 1.046099, Train acc 0.715279, Valid acc 0.731898, Time 545.8 sec, Total time 01:58:07, lr 0.01
# Epoch 13. Loss: 1.019903, Train acc 0.722860, Valid acc 0.747554, Time 547.4 sec, Total time 02:07:14, lr 0.01
# Epoch 14. Loss: 0.998013, Train acc 0.724842, Valid acc 0.717710, Time 546.5 sec, Total time 02:16:21, lr 0.01
# Epoch 15. Loss: 0.984727, Train acc 0.728562, Valid acc 0.731409, Time 538.9 sec, Total time 02:25:19, lr 0.01
# Epoch 16. Loss: 0.967565, Train acc 0.733013, Valid acc 0.747065, Time 542.8 sec, Total time 02:34:22, lr 0.01
# Epoch 17. Loss: 0.946160, Train acc 0.740907, Valid acc 0.755871, Time 545.2 sec, Total time 02:43:27, lr 0.01
# Epoch 18. Loss: 0.934101, Train acc 0.742472, Valid acc 0.713796, Time 547.4 sec, Total time 02:52:35, lr 0.01
# Epoch 19. Loss: 0.923641, Train acc 0.745114, Valid acc 0.746086, Time 543.9 sec, Total time 03:01:39, lr 0.01
# Epoch 20. Loss: 0.919558, Train acc 0.745427, Valid acc 0.754403, Time 544.2 sec, Total time 03:10:43, lr 0.01
# Epoch 21. Loss: 0.891718, Train acc 0.752695, Valid acc 0.750000, Time 545.6 sec, Total time 03:19:49, lr 0.01
# Epoch 22. Loss: 0.875779, Train acc 0.756555, Valid acc 0.765656, Time 543.4 sec, Total time 03:28:52, lr 0.01
# Epoch 23. Loss: 0.872805, Train acc 0.756277, Valid acc 0.760763, Time 551.6 sec, Total time 03:38:04, lr 0.01
# Epoch 24. Loss: 0.858119, Train acc 0.762814, Valid acc 0.760763, Time 549.7 sec, Total time 03:47:13, lr 0.01
# Epoch 25. Loss: 0.851242, Train acc 0.764344, Valid acc 0.758806, Time 542.6 sec, Total time 03:56:16, lr 0.01
# Epoch 26. Loss: 0.840690, Train acc 0.767578, Valid acc 0.772505, Time 539.8 sec, Total time 04:05:16, lr 0.01
# Epoch 27. Loss: 0.830442, Train acc 0.767404, Valid acc 0.763699, Time 546.7 sec, Total time 04:14:22, lr 0.01
# Epoch 28. Loss: 0.822135, Train acc 0.773315, Valid acc 0.758806, Time 543.8 sec, Total time 04:23:26, lr 0.01
# Epoch 29. Loss: 0.832202, Train acc 0.770464, Valid acc 0.763699, Time 545.9 sec, Total time 04:32:32, lr 0.01
# Epoch 30. Loss: 0.815268, Train acc 0.772655, Valid acc 0.780333, Time 536.2 sec, Total time 04:41:28, lr 0.01
# Epoch 31. Loss: 0.807062, Train acc 0.774358, Valid acc 0.775930, Time 544.8 sec, Total time 04:50:33, lr 0.01
# Epoch 32. Loss: 0.807113, Train acc 0.774706, Valid acc 0.792074, Time 546.3 sec, Total time 04:59:39, lr 0.01
# Epoch 33. Loss: 0.800331, Train acc 0.776653, Valid acc 0.777886, Time 539.5 sec, Total time 05:08:39, lr 0.01
# Epoch 34. Loss: 0.785363, Train acc 0.778044, Valid acc 0.790607, Time 541.6 sec, Total time 05:17:40, lr 0.01
# Epoch 35. Loss: 0.763868, Train acc 0.785764, Valid acc 0.776419, Time 548.5 sec, Total time 05:26:49, lr 0.01
# Epoch 36. Loss: 0.766117, Train acc 0.784721, Valid acc 0.797456, Time 549.3 sec, Total time 05:35:58, lr 0.01
# Epoch 37. Loss: 0.769572, Train acc 0.785347, Valid acc 0.775440, Time 544.1 sec, Total time 05:45:02, lr 0.01
# Epoch 38. Loss: 0.761845, Train acc 0.788268, Valid acc 0.780822, Time 547.9 sec, Total time 05:54:10, lr 0.01
# Epoch 39. Loss: 0.765736, Train acc 0.786077, Valid acc 0.795010, Time 542.1 sec, Total time 06:03:12, lr 0.01
# Epoch 40. Loss: 0.745235, Train acc 0.791362, Valid acc 0.782779, Time 544.3 sec, Total time 06:12:17, lr 0.01
# Epoch 41. Loss: 0.734919, Train acc 0.795118, Valid acc 0.798924, Time 546.8 sec, Total time 06:21:23, lr 0.01
# Epoch 42. Loss: 0.738301, Train acc 0.789659, Valid acc 0.804795, Time 547.0 sec, Total time 06:30:30, lr 0.01
# Epoch 43. Loss: 0.740592, Train acc 0.794492, Valid acc 0.802838, Time 542.2 sec, Total time 06:39:33, lr 0.01
# Epoch 44. Loss: 0.729134, Train acc 0.794388, Valid acc 0.803327, Time 543.8 sec, Total time 06:48:36, lr 0.01
# Epoch 45. Loss: 0.728233, Train acc 0.797656, Valid acc 0.790117, Time 543.3 sec, Total time 06:57:40, lr 0.01
# Epoch 46. Loss: 0.716493, Train acc 0.798908, Valid acc 0.786204, Time 542.6 sec, Total time 07:06:42, lr 0.01
# Epoch 47. Loss: 0.724473, Train acc 0.795535, Valid acc 0.807730, Time 547.1 sec, Total time 07:15:49, lr 0.01
# Epoch 48. Loss: 0.705095, Train acc 0.803915, Valid acc 0.797945, Time 547.6 sec, Total time 07:24:57, lr 0.01
# Epoch 49. Loss: 0.698995, Train acc 0.804924, Valid acc 0.792074, Time 540.8 sec, Total time 07:33:58, lr 0.01
# Epoch 50. Loss: 0.694851, Train acc 0.805932, Valid acc 0.807241, Time 546.2 sec, Total time 07:43:04, lr 0.01
# Epoch 51. Loss: 0.706662, Train acc 0.803881, Valid acc 0.787671, Time 546.7 sec, Total time 07:52:11, lr 0.01
# Epoch 52. Loss: 0.680786, Train acc 0.808297, Valid acc 0.811155, Time 545.7 sec, Total time 08:01:17, lr 0.01
# Epoch 53. Loss: 0.685621, Train acc 0.806523, Valid acc 0.817515, Time 547.4 sec, Total time 08:10:24, lr 0.01
# Epoch 54. Loss: 0.677736, Train acc 0.812817, Valid acc 0.797456, Time 545.8 sec, Total time 08:19:30, lr 0.01
# Epoch 55. Loss: 0.675084, Train acc 0.810974, Valid acc 0.811155, Time 545.9 sec, Total time 08:28:36, lr 0.01
# Epoch 56. Loss: 0.671657, Train acc 0.811392, Valid acc 0.818493, Time 542.5 sec, Total time 08:37:38, lr 0.01
# Epoch 57. Loss: 0.673213, Train acc 0.812226, Valid acc 0.806751, Time 542.4 sec, Total time 08:46:40, lr 0.01
# Epoch 58. Loss: 0.676576, Train acc 0.810314, Valid acc 0.806751, Time 545.7 sec, Total time 08:55:46, lr 0.01
# Epoch 59. Loss: 0.665483, Train acc 0.813165, Valid acc 0.824853, Time 546.0 sec, Total time 09:04:52, lr 0.01
# Epoch 60. Loss: 0.662987, Train acc 0.816051, Valid acc 0.811155, Time 538.9 sec, Total time 09:13:51, lr 0.01
# Epoch 61. Loss: 0.661986, Train acc 0.814695, Valid acc 0.793053, Time 544.7 sec, Total time 09:22:56, lr 0.01
# Epoch 62. Loss: 0.648701, Train acc 0.817616, Valid acc 0.828767, Time 545.9 sec, Total time 09:32:02, lr 0.01
# Epoch 63. Loss: 0.635391, Train acc 0.823180, Valid acc 0.826321, Time 540.1 sec, Total time 09:41:02, lr 0.01
# Epoch 64. Loss: 0.643276, Train acc 0.819598, Valid acc 0.827789, Time 544.6 sec, Total time 09:50:06, lr 0.01
# Epoch 65. Loss: 0.638362, Train acc 0.821511, Valid acc 0.831703, Time 544.0 sec, Total time 09:59:10, lr 0.01
# Epoch 66. Loss: 0.632561, Train acc 0.823666, Valid acc 0.820939, Time 544.9 sec, Total time 10:08:15, lr 0.01
# Epoch 67. Loss: 0.623597, Train acc 0.825301, Valid acc 0.817025, Time 541.1 sec, Total time 10:17:16, lr 0.01
# Epoch 68. Loss: 0.619049, Train acc 0.827978, Valid acc 0.806751, Time 544.1 sec, Total time 10:26:20, lr 0.01
# Epoch 69. Loss: 0.634395, Train acc 0.820746, Valid acc 0.777886, Time 542.3 sec, Total time 10:35:23, lr 0.01
# Epoch 70. Loss: 0.631550, Train acc 0.825892, Valid acc 0.815558, Time 548.5 sec, Total time 10:44:31, lr 0.01
# Epoch 71. Loss: 0.613224, Train acc 0.829995, Valid acc 0.825342, Time 543.3 sec, Total time 10:53:34, lr 0.01
# Epoch 72. Loss: 0.619845, Train acc 0.825961, Valid acc 0.820939, Time 542.1 sec, Total time 11:02:37, lr 0.01
# Epoch 73. Loss: 0.616558, Train acc 0.828430, Valid acc 0.828767, Time 548.7 sec, Total time 11:11:45, lr 0.01
# Epoch 74. Loss: 0.611331, Train acc 0.828604, Valid acc 0.815558, Time 540.9 sec, Total time 11:20:46, lr 0.01
# Epoch 75. Loss: 0.611579, Train acc 0.827770, Valid acc 0.813601, Time 544.0 sec, Total time 11:29:50, lr 0.01
# Epoch 76. Loss: 0.611752, Train acc 0.828674, Valid acc 0.817515, Time 542.3 sec, Total time 11:38:52, lr 0.01
# Epoch 77. Loss: 0.613729, Train acc 0.827700, Valid acc 0.808219, Time 542.3 sec, Total time 11:47:55, lr 0.01
# Epoch 78. Loss: 0.605005, Train acc 0.830586, Valid acc 0.814090, Time 540.7 sec, Total time 11:56:55, lr 0.01
# Epoch 79. Loss: 0.608234, Train acc 0.830447, Valid acc 0.823875, Time 542.6 sec, Total time 12:05:58, lr 0.01
# Epoch 80. Loss: 0.608563, Train acc 0.832221, Valid acc 0.837573, Time 547.6 sec, Total time 12:15:06, lr 0.01
# Epoch 81. Loss: 0.608108, Train acc 0.830204, Valid acc 0.820450, Time 539.0 sec, Total time 12:24:05, lr 0.01
# Epoch 82. Loss: 0.595252, Train acc 0.833090, Valid acc 0.838063, Time 541.9 sec, Total time 12:33:06, lr 0.01
# Epoch 83. Loss: 0.586776, Train acc 0.838410, Valid acc 0.818982, Time 542.9 sec, Total time 12:42:09, lr 0.01
# Epoch 84. Loss: 0.584602, Train acc 0.837645, Valid acc 0.841977, Time 543.3 sec, Total time 12:51:13, lr 0.01
# Epoch 85. Loss: 0.600532, Train acc 0.831908, Valid acc 0.834149, Time 547.5 sec, Total time 13:00:20, lr 0.01
# Epoch 86. Loss: 0.593122, Train acc 0.833959, Valid acc 0.821429, Time 538.4 sec, Total time 13:09:19, lr 0.01
# Epoch 87. Loss: 0.576991, Train acc 0.837158, Valid acc 0.836595, Time 540.3 sec, Total time 13:18:19, lr 0.01
# Epoch 88. Loss: 0.575793, Train acc 0.839558, Valid acc 0.828278, Time 541.0 sec, Total time 13:27:20, lr 0.01
# Epoch 89. Loss: 0.577758, Train acc 0.841644, Valid acc 0.818004, Time 545.1 sec, Total time 13:36:25, lr 0.01
# Epoch 90. Loss: 0.563432, Train acc 0.844043, Valid acc 0.827789, Time 551.0 sec, Total time 13:45:36, lr 0.01
# Epoch 91. Loss: 0.574156, Train acc 0.839245, Valid acc 0.834638, Time 545.1 sec, Total time 13:54:41, lr 0.01
# Epoch 92. Loss: 0.574399, Train acc 0.840566, Valid acc 0.809198, Time 544.9 sec, Total time 14:03:46, lr 0.01
# Epoch 93. Loss: 0.573306, Train acc 0.839106, Valid acc 0.834149, Time 542.0 sec, Total time 14:12:48, lr 0.01
# Epoch 94. Loss: 0.560168, Train acc 0.843278, Valid acc 0.847847, Time 542.3 sec, Total time 14:21:50, lr 0.01
# Epoch 95. Loss: 0.564279, Train acc 0.843209, Valid acc 0.824364, Time 549.4 sec, Total time 14:31:00, lr 0.01
# Epoch 96. Loss: 0.557571, Train acc 0.844148, Valid acc 0.848337, Time 546.6 sec, Total time 14:40:06, lr 0.01
# Epoch 97. Loss: 0.565900, Train acc 0.842687, Valid acc 0.829746, Time 547.7 sec, Total time 14:49:14, lr 0.01
# Epoch 98. Loss: 0.557254, Train acc 0.846199, Valid acc 0.830235, Time 547.2 sec, Total time 14:58:21, lr 0.01
# Epoch 99. Loss: 0.560041, Train acc 0.844078, Valid acc 0.838552, Time 541.9 sec, Total time 15:07:23, lr 0.01
# Epoch 100. Loss: 0.558503, Train acc 0.844947, Valid acc 0.824364, Time 546.4 sec, Total time 15:16:29, lr 0.01
# Epoch 101. Loss: 0.538941, Train acc 0.851415, Valid acc 0.850783, Time 545.9 sec, Total time 15:25:35, lr 0.01
# Epoch 102. Loss: 0.559465, Train acc 0.846547, Valid acc 0.843444, Time 548.8 sec, Total time 15:34:44, lr 0.01
# Epoch 103. Loss: 0.549897, Train acc 0.847486, Valid acc 0.839530, Time 544.5 sec, Total time 15:43:49, lr 0.01
# Epoch 104. Loss: 0.550205, Train acc 0.849503, Valid acc 0.840509, Time 541.8 sec, Total time 15:52:50, lr 0.01
# Epoch 105. Loss: 0.543165, Train acc 0.849920, Valid acc 0.840020, Time 540.1 sec, Total time 16:01:50, lr 0.01
# Epoch 106. Loss: 0.522178, Train acc 0.856805, Valid acc 0.846380, Time 543.3 sec, Total time 16:10:54, lr 0.01
# Epoch 107. Loss: 0.546556, Train acc 0.847277, Valid acc 0.854207, Time 544.1 sec, Total time 16:19:58, lr 0.01
# Epoch 108. Loss: 0.521680, Train acc 0.854893, Valid acc 0.845890, Time 542.4 sec, Total time 16:29:00, lr 0.01
# Epoch 109. Loss: 0.531793, Train acc 0.855379, Valid acc 0.842466, Time 543.5 sec, Total time 16:38:04, lr 0.01
# Epoch 110. Loss: 0.526028, Train acc 0.854232, Valid acc 0.854207, Time 542.7 sec, Total time 16:47:06, lr 0.01
# Epoch 111. Loss: 0.534308, Train acc 0.853189, Valid acc 0.853718, Time 544.0 sec, Total time 16:56:10, lr 0.01
# Epoch 112. Loss: 0.538585, Train acc 0.851798, Valid acc 0.849804, Time 548.7 sec, Total time 17:05:19, lr 0.01
# Epoch 113. Loss: 0.528270, Train acc 0.854406, Valid acc 0.840509, Time 544.5 sec, Total time 17:14:24, lr 0.01
# Epoch 114. Loss: 0.533648, Train acc 0.855414, Valid acc 0.859589, Time 543.9 sec, Total time 17:23:27, lr 0.01
# Epoch 115. Loss: 0.519112, Train acc 0.858057, Valid acc 0.861057, Time 545.0 sec, Total time 17:32:33, lr 0.01
# Epoch 116. Loss: 0.509236, Train acc 0.860074, Valid acc 0.842466, Time 549.5 sec, Total time 17:41:42, lr 0.01
# Epoch 117. Loss: 0.514904, Train acc 0.857153, Valid acc 0.855186, Time 546.9 sec, Total time 17:50:49, lr 0.01
# Epoch 118. Loss: 0.519243, Train acc 0.859204, Valid acc 0.848826, Time 542.9 sec, Total time 17:59:52, lr 0.01
# Epoch 119. Loss: 0.520798, Train acc 0.857222, Valid acc 0.844423, Time 539.1 sec, Total time 18:08:51, lr 0.01
# Epoch 120. Loss: 0.507130, Train acc 0.860421, Valid acc 0.843933, Time 543.3 sec, Total time 18:17:54, lr 0.01
# Epoch 121. Loss: 0.503000, Train acc 0.863064, Valid acc 0.854697, Time 544.2 sec, Total time 18:26:58, lr 0.01
# Epoch 122. Loss: 0.506385, Train acc 0.861117, Valid acc 0.865460, Time 540.3 sec, Total time 18:35:59, lr 0.01
# Epoch 123. Loss: 0.508960, Train acc 0.860908, Valid acc 0.851761, Time 543.0 sec, Total time 18:45:02, lr 0.01
# Epoch 124. Loss: 0.491345, Train acc 0.864838, Valid acc 0.866928, Time 546.8 sec, Total time 18:54:09, lr 0.01
# Epoch 125. Loss: 0.504965, Train acc 0.860595, Valid acc 0.848337, Time 546.0 sec, Total time 19:03:15, lr 0.01
# Epoch 126. Loss: 0.496892, Train acc 0.863934, Valid acc 0.854697, Time 543.5 sec, Total time 19:12:18, lr 0.01
# Epoch 127. Loss: 0.495544, Train acc 0.864246, Valid acc 0.864971, Time 543.8 sec, Total time 19:21:22, lr 0.01
# Epoch 128. Loss: 0.505348, Train acc 0.861882, Valid acc 0.854697, Time 547.3 sec, Total time 19:30:29, lr 0.01
# Epoch 129. Loss: 0.505990, Train acc 0.862786, Valid acc 0.856654, Time 542.8 sec, Total time 19:39:32, lr 0.01
# Epoch 130. Loss: 0.501767, Train acc 0.862716, Valid acc 0.852740, Time 542.8 sec, Total time 19:48:35, lr 0.01
# Epoch 131. Loss: 0.496350, Train acc 0.863725, Valid acc 0.857143, Time 544.4 sec, Total time 19:57:39, lr 0.01
# Epoch 132. Loss: 0.499409, Train acc 0.863064, Valid acc 0.843933, Time 545.7 sec, Total time 20:06:45, lr 0.01
# Epoch 133. Loss: 0.487667, Train acc 0.865637, Valid acc 0.853718, Time 542.3 sec, Total time 20:15:47, lr 0.01
# Epoch 134. Loss: 0.488848, Train acc 0.864977, Valid acc 0.855675, Time 542.0 sec, Total time 20:24:49, lr 0.01
# Epoch 135. Loss: 0.487517, Train acc 0.866402, Valid acc 0.870841, Time 547.5 sec, Total time 20:33:57, lr 0.01
# Epoch 136. Loss: 0.492581, Train acc 0.866541, Valid acc 0.856654, Time 540.2 sec, Total time 20:42:57, lr 0.01
# Epoch 137. Loss: 0.478517, Train acc 0.868732, Valid acc 0.849804, Time 538.3 sec, Total time 20:51:55, lr 0.01
# Epoch 138. Loss: 0.487532, Train acc 0.868489, Valid acc 0.852250, Time 543.2 sec, Total time 21:00:58, lr 0.01
# Epoch 139. Loss: 0.484731, Train acc 0.867550, Valid acc 0.854207, Time 542.4 sec, Total time 21:10:01, lr 0.01
# Epoch 140. Loss: 0.483862, Train acc 0.866402, Valid acc 0.880137, Time 537.9 sec, Total time 21:18:58, lr 0.01
# Epoch 141. Loss: 0.490798, Train acc 0.865324, Valid acc 0.863992, Time 538.6 sec, Total time 21:27:57, lr 0.01
# Epoch 142. Loss: 0.479685, Train acc 0.870193, Valid acc 0.852740, Time 543.4 sec, Total time 21:37:00, lr 0.01
# Epoch 143. Loss: 0.478504, Train acc 0.867376, Valid acc 0.871331, Time 543.2 sec, Total time 21:46:04, lr 0.01
# Epoch 144. Loss: 0.483459, Train acc 0.868315, Valid acc 0.856654, Time 541.8 sec, Total time 21:55:06, lr 0.01
# Epoch 145. Loss: 0.474727, Train acc 0.871027, Valid acc 0.871331, Time 543.6 sec, Total time 22:04:09, lr 0.01
# Epoch 146. Loss: 0.471870, Train acc 0.872801, Valid acc 0.861546, Time 545.9 sec, Total time 22:13:15, lr 0.01
# Epoch 147. Loss: 0.469581, Train acc 0.871271, Valid acc 0.847847, Time 545.6 sec, Total time 22:22:21, lr 0.01
# Epoch 148. Loss: 0.482653, Train acc 0.871410, Valid acc 0.868885, Time 545.2 sec, Total time 22:31:26, lr 0.01
# Epoch 149. Loss: 0.462867, Train acc 0.874609, Valid acc 0.878180, Time 545.5 sec, Total time 22:40:31, lr 0.01
# Epoch 150. Loss: 0.470132, Train acc 0.873496, Valid acc 0.867417, Time 548.1 sec, Total time 22:49:40, lr 0.001
# Epoch 151. Loss: 0.471454, Train acc 0.872349, Valid acc 0.867906, Time 547.6 sec, Total time 22:58:47, lr 0.001
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-fda0873e9498> in <module>()
# ----> 1 train(finetune_net, ctx)
#
# <ipython-input-13-76daa926a426> in train(net, ctx, epochs, learning_rate, wd)
#      13         if count >= 820:
#      14             i.lr_mult = learning_rate * 10
# ---> 15     util_train(train_data, valid_data, net, loss, trainer, ctx, epochs, lr_period, lr_decay)
#
# <ipython-input-12-70760be123e4> in util_train(train_data, test_data, net, loss, trainer, ctx, num_epochs, lr_period, lr_decay, print_batches)
#      21                 l.backward()
#      22             train_acc += sum([(yhat.argmax(axis=1)==y).sum().asscalar()
# ---> 23                               for yhat, y in zip(outputs, label)])
#      24             train_loss += sum([l.sum().asscalar() for l in losses])
#      25             trainer.step(batch_size)
#
# <ipython-input-12-70760be123e4> in <listcomp>(.0)
#      21                 l.backward()
#      22             train_acc += sum([(yhat.argmax(axis=1)==y).sum().asscalar()
# ---> 23                               for yhat, y in zip(outputs, label)])
#      24             train_loss += sum([l.sum().asscalar() for l in losses])
#      25             trainer.step(batch_size)
#
# ~/anaconda3/lib/python3.6/site-packages/mxnet/ndarray/ndarray.py in asscalar(self)
#    1809         if self.shape != (1,):
#    1810             raise ValueError("The current array is not a scalar")
# -> 1811         return self.asnumpy()[0]
#    1812
#    1813     def astype(self, dtype):
#
# ~/anaconda3/lib/python3.6/site-packages/mxnet/ndarray/ndarray.py in asnumpy(self)
#    1791             self.handle,
#    1792             data.ctypes.data_as(ctypes.c_void_p),
# -> 1793             ctypes.c_size_t(data.size)))
#    1794         return data
#    1795
#
# KeyboardInterrupt:

# %%
pred = []
for data, label in test_data:
    output = nd.softmax(finetune_net(data.as_in_context(ctx[0])))
    pred.extend(output.asnumpy())

# %%
ids = sorted(os.listdir('/home/samael/kaggle/dogs/data/test/unknown'))
with open('submission.csv', 'w') as f:
    f.write('id,' + ','.join(train_ds.synsets) + '\n')
    for i, output in zip(ids, pred):
        f.write(i.split('.')[0] + ',' + ','.join([str(num) for num in output]) + '\n')
